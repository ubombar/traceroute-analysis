# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path("../src")))

import sqlite3
import pandas as pd

db_file = Path("../data/20260512153600__stream_retina__1h.db")  # change to your db file
# db_file = Path("../data/20260512232821__stream_retina__5s.db")  # change to your db file
con = sqlite3.connect(db_file)

# %%
df = pd.read_sql("SELECT * FROM fies", con)
# timestamp_cols = [col for col in df.columns if col.endswith("_timestamp")]

# for col in timestamp_cols:
#     df[col] = pd.to_datetime(df[col], unit="s", utc=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 708 entries, 0 to 707
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   agent_id                 708 non-null    str
#  1   probing_directive_id     708 non-null    int64
#  2   sequence_number          708 non-null    int64
#  3   ip_version               708 non-null    int64
#  4   protocol                 708 non-null    int64
#  5   source_address           708 non-null    str
#  6   destination_address      708 non-null    str
#  7   near_probe_ttl           708 non-null    int64
#  8   near_reply_address       708 non-null    str
#  9   near_sent_timestamp      708 non-null    str
#  10  near_received_timestamp  708 non-null    str
#  11  far_probe_ttl            708 non-null    int64
#  12  far_reply_address        708 non-null    str
#  13  far_sent_timestamp       708 non-null    str
#  14  far_received_timestamp   708 non-null    str
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 546773 entries, 0 to 546772
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   agent_id                 546773 non-null  str
#  1   probing_directive_id     546773 non-null  int64
#  2   sequence_number          546773 non-null  int64
#  3   ip_version               546773 non-null  int64
#  4   protocol                 546773 non-null  int64
#  5   source_address           546773 non-null  str
#  6   destination_address      546773 non-null  str
#  7   near_probe_ttl           546773 non-null  int64
#  8   near_reply_address       546773 non-null  str
#  9   near_sent_timestamp      546773 non-null  str
#  10  near_received_timestamp  546773 non-null  str
#  11  far_probe_ttl            546773 non-null  int64
#  12  far_reply_address        546773 non-null  str
#  13  far_sent_timestamp       546773 non-null  str
# ...

# %%
df
# Out:
#                       agent_id  probing_directive_id  sequence_number  \
# 0           retina-asia-south1               7608841                0
# 1           retina-asia-south1                973687                1
# 2           retina-asia-south1               7163556                2
# 3         retina-europe-north1               9889103                3
# 4         retina-europe-north1               6246022                4
# ...                        ...                   ...              ...
# 546768  retina-asia-southeast1               8041465           546768
# 546769  retina-asia-southeast1               2655188           546769
# 546770  retina-asia-southeast1               3379584           546770
# 546771         retina-us-west4               7559865           546771
# 546772         retina-us-west4               1083885           546772
#
#         ip_version  protocol source_address destination_address  \
# ...
